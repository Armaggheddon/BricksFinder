# %% [markdown]
# ![BricksFinder](data:image/png;base64,...)

# %% [markdown]
# # BricksFinder Live Demo 🚀🧱
# Welcome to the BricksFinder live demo, where LEGO meets AI magic! ✨🔍 This notebook lets you explore the power of BricksFinder directly in your browser. Search for LEGO minifigures (and soon bricks!) using text or images through a sleek Web UI.

# %% [markdown]
# ## Getting Started 🚦
# Before diving into the LEGO adventure, let’s set things up:
# 1. Head to the menu bar and click **Runtime** > **Change runtime type**.
# 2. Under **Hardware accelerator**, select any of the **GPU** options available (**T4 GPU** is available for free).
# 3. Hit **Save** and you're all set to go! 🚀
#
# <div class="alert alert-block alert-info">
# <b>💡 Tip:</b>
# For the best experience, enable the GPU by selecting <b>Runtime</b> > <b>Change runtime type</b> > <b>Hardware accelerator</b> > <b>GPU</b>. While BricksFinder will still work without a GPU, index building will take significantly more time—especially for the minifigure index, which takes approximately 5 minutes with a GPU. Don't let the wait slow down your LEGO fun! ⚡
# </div>

# %% [markdown]
# ## What's inside? 📦
# This notebook is your express ticket to LEGO-powered fun, with just two cells to rule them all:
#
# ### 1. **Clone and install** 🖥️
# The first cell is your setup wizard:
# - **Clones** the BricksFinder GitHub repository like a pro.
# - **Installs** all the dependencies faster than you can say "minifigure"!
#
# 🏁 Start here to prepare your environment for awesomeness.

# %%
# !git clone https://github.com/Armaggheddon/BricksFinder.git
# %cd BricksFinder
# %cd bricks_finder
# !pip install -r gpu-requirements.txt

# %% [markdown]
# ### 3. **Launch the Web UI** 🌐
# The second cell is where the magic happens:
# - Launches the **BricksFinder Web UI**. Click on the **public link** to use on Colab.
# - Customize the startup index with the parameter `--startup_index` to start with either `minifigures` (ready to go!) or `bricks` (coming soon 🚧).
#
# <div class="alert alert-block alert-warning">
# <b>⚠️ Warning:</b> Starting up BricksFinder might take some time depending on the GPU you’re using and the <code>--startup_index</code> selected:
# <ul>
# <li>- For the <code>minifigure</code> index, it will take approximately 5 minutes to build the index on the Tesla T4 GPU.</li>
# <li>- For the <code>brick</code> index (once available), startup time will be updated.</li>
# </ul>
#
# Please be patient while the system gets everything ready for your LEGO search adventure! 🚀
#
# </div>

# %%
# !python3 src/main.py --share --startup_index=minifigure
